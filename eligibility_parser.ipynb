# %% [markdown]
# ## Load SciSpaCy and the Model
# # This code loads the SciSpaCy medical NLP model
# # Processess a sample eligibility statement
# # Shows the entities it recognized (like conditions, scores, medications)

# %%
# Load the clinical model from SciSpaCy
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# -------------------------------------------------------------------
# OSError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load the clinical model from SciSpaCy
#       2 import spacy
# ----> 3 nlp = spacy.load("en_core_web_sm")
#
# File ~\anaconda3\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~\anaconda3\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
# Sample sentence from the trial
text = "PHQ-9 score >= 10 at screening"

# %%
# Process the text
text = "PHQ-0 score >=10 at screening"
doc = nlp(text)

# %%
# Display named entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# PHQ-0 ENTITY
# screening ENTITY

# %% [markdown]
# ## Add your full criteria list to the notebook

# %%
criteria = {
    "inclusion": [
        "18 Years to 70 Years (Adult, Older Adult)"
        "Veteran of OEF/OIF/OND deployments",
        "Depressive severity of >= 10 on the PHQ-9 at screening",
        "Patient may also have a DSM-5 56 diagnosis of unipolar Major Depression; PTSD; any anxiety disorder; substance/alcohol abuse; or adjustment disorder",
        "Ability to read = eighth grade level",
        "Can provide informed consent",
        "Patients may be taking antidepressants/antianxiety medications where dose has been stable >= 4 weeks prior to screening evaluation",
        "Must have an Android smartphone",
        "Must be willing to be audio-taped for fidelity ratings"
    ],
    "exclusion": [
        "Diagnoses of schizophrenia, schizo-affective, bipolar, or other psychotic disorder",
        "Serious suicidal risk (Patient responds positively to PHQ-9 question #9)",
        "Severe PTSD (Score > 51 on PTSD Checklist for DSM-5)",
        "Severe substance or alcohol dependence (meets DSM-5 criteria of severe)"
    ]
}

# %% [markdown]
# ## Process and display entities with labels
# # A list of each inlcusion/exlusion statement
# # Any recognized entities (like conditions, scores, time periods)

# %%
for label, statements in criteria.items():
    print(f"\n== {label.upper()} CRITERIA ===")
    for stmt in statements:
        doc = nlp(stmt)
        print(f"\n🔹{stmt}")
        for ent in doc.ents:
            print(f"  - {ent.text} -> {ent.label_}")
# Out:
# == INCLUSION CRITERIA ===
#
# 🔹18 Years to 70 Years (Adult, Older Adult)Veteran of OEF/OIF/OND deployments
#   - Years -> ENTITY
#   - Adult -> ENTITY
#   - Older Adult)Veteran -> ENTITY
#   - OEF/OIF/OND deployments -> ENTITY
#
# 🔹Depressive severity of >= 10 on the PHQ-9 at screening
#   - Depressive severity -> ENTITY
#   - PHQ-9 -> ENTITY
#   - screening -> ENTITY
#
# 🔹Patient may also have a DSM-5 56 diagnosis of unipolar Major Depression; PTSD; any anxiety disorder; substance/alcohol abuse; or adjustment disorder
#   - Patient -> ENTITY
#   - DSM-5 -> ENTITY
#   - diagnosis -> ENTITY
#   - unipolar Major Depression -> ENTITY
#   - PTSD -> ENTITY
#   - anxiety disorder -> ENTITY
#   - substance/alcohol abuse -> ENTITY
#   - adjustment disorder -> ENTITY
#
# 🔹Ability to read = eighth grade level
#   - level -> ENTITY
#
# 🔹Can provide informed consent
#
# 🔹Patients may be taking antidepressants/antianxiety medications where dose has been stable >= 4 weeks prior to screening evaluation
#   - Patients -> ENTITY
#   - antidepressants/antianxiety medications -> ENTITY
#   - dose -> ENTITY
#   - stable -> ENTITY
#   - weeks -> ENTITY
#   - screening evaluation -> ENTITY
#
# 🔹Must have an Android smartphone
#   - Android smartphone -> ENTITY
#
# 🔹Must be willing to be audio-taped for fidelity ratings
#   - audio-taped -> ENTITY
#   - fidelity -> ENTITY
#   - ratings -> ENTITY
#
# == EXCLUSION CRITERIA ===
#
# 🔹Diagnoses of schizophrenia, schizo-affective, bipolar, or other psychotic disorder
#   - Diagnoses -> ENTITY
#   - schizophrenia -> ENTITY
#   - schizo-affective -> ENTITY
#   - bipolar -> ENTITY
#   - psychotic disorder -> ENTITY
#
# 🔹Serious suicidal risk (Patient responds positively to PHQ-9 question #9)
#   - suicidal risk -> ENTITY
#   - Patient responds -> ENTITY
#   - PHQ-9 -> ENTITY
#   - question -> ENTITY
#
# 🔹Severe PTSD (Score > 51 on PTSD Checklist for DSM-5)
#   - Severe -> ENTITY
#   - PTSD -> ENTITY
#   - Score -> ENTITY
#   - PTSD -> ENTITY
#   - DSM-5 -> ENTITY
#
# 🔹Severe substance or alcohol dependence (meets DSM-5 criteria of severe)
#   - Severe substance -> ENTITY
#   - alcohol dependence -> ENTITY
#   - meets DSM-5 criteria of severe -> ENTITY

# %% [markdown]
# ## Structuring eligibility criteria as concepts (diagnosis, symptoms, medications) - JSON format for future downstream matching with Synthea patients
# # JSON because it gives a clean, machine-readable way to store inclusion/exclusion rules
# # A structure you can use to match against patient data fields
# # Easy way to extend rules later (eg. to add thresholds, severity, conditions, meds)

# %%
structured_criteria = {
    "inclusion": [
        {"id": 1,
            "concepts": ["veteran", "OEF/OIF/OND"],
            "field": "military_history",
            "priority": "high",
            "weight": 10
        },
        {"id": 2,
            "concepts": ["PHQ-9", "phq9", "depressive severity"],
            "field": "mental_health_assessment",
            "priority": "high",
            "weight": 9 
        },
        {"id": 3,
            "concepts": ["major depression", "PTSD", "anxiety", "substance abuse", "adjustment disorder"],
            "field": "conditions",
            "priority": "high",
            "weight": 8    
        },
        {"id": 4,
            "concepts": ["age 18", "age 70", "adult"],
            "field": "demographics",
            "priority": "high",
            "weight": 10
        },
        {"id": 5,
            "concepts": ["eighth grade reading level"],
            "field": "literacy",
            "priority": "medium",
            "weight": 5
        },
        {"id": 6,
            "concepts": ["informed consent"],
            "field": "legal_consent",
            "priority": "medium",
            "weight": 6
        },
        {"id": 7,
            "concepts": ["antidepressant", "antianxiety", "stable dose", "4 weeks"],
            "field": "medications",
            "priority": "medium",
            "weight": 6
        },
        {"id": 8,
            "concepts": ["android smartphone"],
            "field": "device",
            "priority": "low",
            "weight": 10
        },
        {"id": 9,
            "concepts": ["audio-taped", "recorded", "fidelity"],
            "field": "consent_media",
            "priority": "low",
            "weight": 2
        },
    ],
    "exclusion": [
        {"id": 1, "concepts": ["schizophrenia", "schizo-affective", "bipolar", "psychotic disorder"], "field": "conditions"},
        {"id": 2, "concepts": ["suicidal risk", "PHQ-9 question 9"], "field": "mental_health"},
        {"id": 3, "concepts": ["severe PTSD", "PTSD Checkkist", "score >51"], "field": "conditions"},
        {"id": 4, "concepts": ["severe substance or alcohol dependence", "DSM-5 criteria severe"], "field": "conditions"},
    ]
}

# %%
# Adjusting to the Ubuntu QuickUMLS data path
from quickumls import QuickUMLS

matcher = QuickUMLS(
    '/mnt/c/Users/Gauri/QuickUMLS/quickumls_data',
    threshold=0.85,
    similarity_name='jaccard',
    window=5
)

def map_concepts_with_quickumls(concepts):
    mapped = set()
    for concept in concepts:
        matches = matcher.match(concept, best_match=True, ignore_syntax=False)
        print(f"Matching '{concept}' => {matches}")  # DEBUG
        for m in matches:
            for candidate in m:
                if candidate['source'] == 'SNOMEDCT_US':
                    mapped.add(candidate['term'].lower())
    return list(mapped) if mapped else concepts

# Fields to map
mapped_fields = {'conditions', 'mental_health_assessment', 'mental_health', 'medications'}

def map_structured_criteria(criteria):
    updated = {"inclusion": [], "exclusion": []}
    for section in ['inclusion', 'exclusion']:
        for rule in criteria[section]:
            updated_rule = rule.copy()
            if rule['field'] in mapped_fields:
                updated_rule['concepts'] = map_concepts_with_quickumls(rule['concepts'])
            updated[section].append(updated_rule)
    return updated

mapped_criteria = map_structured_criteria(structured_criteria)

print(mapped_criteria)
# Out:
# Matching 'PHQ-9' => []
# Matching 'phq9' => []
# Matching 'depressive severity' => []
# Matching 'major depression' => []
# Matching 'PTSD' => []
# Matching 'anxiety' => []
# Matching 'substance abuse' => []
# Matching 'adjustment disorder' => []
# Matching 'antidepressant' => []
# Matching 'antianxiety' => []
# Matching 'stable dose' => []
# Matching '4 weeks' => []
# Matching 'schizophrenia' => []
# Matching 'schizo-affective' => []
# Matching 'bipolar' => []
# Matching 'psychotic disorder' => []
# Matching 'suicidal risk' => []
# Matching 'PHQ-9 question 9' => []
# Matching 'severe PTSD' => []
# Matching 'PTSD Checkkist' => []
# Matching 'score >51' => []
# Matching 'severe substance or alcohol dependence' => []
# Matching 'DSM-5 criteria severe' => []
# {'inclusion': [{'id': 1, 'concepts': ['veteran', 'OEF/OIF/OND'], 'field': 'military_history', 'priority': 'high', 'weight': 10}, {'id': 2, 'concepts': ['PHQ-9', 'phq9', 'depressive severity'], 'field': 'mental_health_assessment', 'priority': 'high', 'weight': 9}, {'id': 3, 'concepts': ['major depression', 'PTSD', 'anxiety', 'substance abuse', 'adjustment disorder'], 'field': 'conditions', 'priority': 'high', 'weight': 8}, {'id': 4, 'concepts': ['age 18', 'age 70', 'adult'], 'field': 'demographics', 'priority': 'high', 'weight': 10}, {'id': 5, 'concepts': ['eighth grade reading level'], 'field': 'literacy', 'priority': 'medium', 'weight': 5}, {'id': 6, 'concepts': ['informed consent'], 'field': 'legal_consent', 'priority': 'medium', 'weight': 6}, {'id': 7, 'concepts': ['antidepressant', 'antianxiety', 'stable dose', '4 weeks'], 'field': 'medications', 'priority': 'medium', 'weight': 6}, {'id': 8, 'concepts': ['android smartphone'], 'field': 'device', 'priority': 'low', 'weight': 10}, {'id': 9, 'concepts': ['audio-taped', 'recorded', 'fidelity'], 'field': 'consent_media', 'priority': 'low', 'weight': 2}], 'exclusion': [{'id': 1, 'concepts': ['schizophrenia', 'schizo-affective', 'bipolar', 'psychotic disorder'], 'field': 'conditions'}, {'id': 2, 'concepts': ['suicidal risk', 'PHQ-9 question 9'], 'field': 'mental_health'}, {'id': 3, 'concepts': ['severe PTSD', 'PTSD Checkkist', 'score >51'], 'field': 'conditions'}, {'id': 4, 'concepts': ['severe substance or alcohol dependence', 'DSM-5 criteria severe'], 'field': 'conditions'}]}

# %%
test_concepts = [
    "major depressive disorder",
    "post-traumatic stress disorder",
    "schizophrenia",
    "suicidal ideation",
    "bipolar disorder",
    "antidepressant",
    "anxiety disorder"
]

def map_concepts_with_quickumls(concepts):
    mapped = set()
    for concept in concepts:
        matches = matcher.match(concept, best_match=True, ignore_syntax=False)
        print(f"\n=== Matches for '{concept}' ===")
        for m in matches:
            for candidate in m:
                print(candidate)  # Print all candidates
                if candidate['source'] == 'SNOMEDCT_US':
                    mapped.add(candidate['term'].lower())
    return list(mapped) if mapped else concepts

mapped = map_concepts_with_quickumls(test_concepts)
print("\n✅ Mapped terms:", mapped)
# Out:
# === Matches for 'major depressive disorder' ===
#
# === Matches for 'post-traumatic stress disorder' ===
#
# === Matches for 'schizophrenia' ===
#
# === Matches for 'suicidal ideation' ===
#
# === Matches for 'bipolar disorder' ===
#
# === Matches for 'antidepressant' ===
#
# === Matches for 'anxiety disorder' ===
#
# ✅ Mapped terms: ['major depressive disorder', 'post-traumatic stress disorder', 'schizophrenia', 'suicidal ideation', 'bipolar disorder', 'antidepressant', 'anxiety disorder']

# %%
import json
import os
from docx import Document

# Load patient JSON
def load_patient_conditions(json_path):
    with open(json_path, 'r') as file:
        data = json.load(file)

    conditions = []
    for entry in data.get('entry', []):
        if entry['resource']['resourceType'] == 'Condition':
            coding = entry['resource'].get('code', {}).get('coding', [])
            if coding:
                display = coding[0].get('display')
                if display:
                    conditions.append(display.lower())
    return conditions

# Match patient against structured criteria
def match_patient_to_criteria(patient_conditions, criteria):
    matched_inclusion = []
    failed_exclusion = []

    for rule in criteria['inclusion']:
        if rule['field'] != 'conditions':
            continue  # For now, evaluating only condition-based criteria

        for term in rule['concepts']:
            if any(term.lower() in cond for cond in patient_conditions):
                matched_inclusion.append(rule['id'])
                break

    for rule in criteria['exclusion']:
        if rule['field'] != 'conditions':
            continue
        for term in rule['concepts']:
            if any(term.lower() in cond for cond in patient_conditions):
                failed_exclusion.append(rule['id'])
                break

    return matched_inclusion, failed_exclusion

# Base input/output paths
input_base = "E:/Gauri/Project/Synthea dataset/output_2/fhir"
output_base = "E:/Gauri/Project/Results/output_2"

# Loop over immediate subfolders in /fhir (e.g., 00, 01)
for top_folder in os.listdir(input_base):
    top_folder_path = os.path.join(input_base, top_folder)
    if not os.path.isdir(top_folder_path):
        continue

    # Create a Word document for each top-level subfolder
    doc = Document()
    doc.add_heading(f'Trial Match Results for Folder: {top_folder}', level=1)
    eligible_patients_found = False  # flag
    
    # Recursively process all JSONs inside this subfolder
    for root, _, files in os.walk(top_folder_path):
        for filename in files:
            if filename.endswith(".json"):
                file_path = os.path.join(root, filename)
                try:
                    conditions = load_patient_conditions(file_path)
                    matched, failed = match_patient_to_criteria(conditions, structured_criteria)

                    if matched and not failed:
                        eligible_patients_found = True
                        doc.add_heading(f'File: {filename}', level=2)
                        doc.add_paragraph(f"Extracted Conditions: {', '.join(conditions)}")
                        doc.add_paragraph(f"Matched Inclusion Criteria IDs: {matched}")
                        doc.add_paragraph(f"Failed Exclusion Criteria IDs: {failed}")
                        doc.add_paragraph("✅ ELIGIBLE")

                except Exception as e:
                    doc.add_heading(f"⚠️ Error reading {filename}", level=2)
                    doc.add_paragraph(str(e))

                    if failed:
                        doc.add_paragraph("❌ NOT ELIGIBLE (Exclusion criteria met)")
                    elif matched:
                        doc.add_paragraph("✅ ELIGIBLE")
                    else:
                        doc.add_paragraph("⚠️ No matching inclusion criteria")

                except Exception as e:
                    doc.add_heading(f"⚠️ Error reading {filename}", level=2)
                    doc.add_paragraph(str(e))

    if eligible_patients_found:
        output_path = os.path.join(output_base, f"Trial_Match_Results_All_Subfolders_{top_folder}.docx")
        doc.save(output_path)
        print(f"✅ Saved: {output_path}")
    else:
        print(f"⚠️ No eligible patients found in folder: {top_folder}")
# Out:
# ⚠️ No eligible patients found in folder: 00
# ⚠️ No eligible patients found in folder: 01
# ⚠️ No eligible patients found in folder: 02
# ⚠️ No eligible patients found in folder: 03
# ⚠️ No eligible patients found in folder: 04
# ⚠️ No eligible patients found in folder: 05
# ⚠️ No eligible patients found in folder: 06
# ⚠️ No eligible patients found in folder: 07
# ⚠️ No eligible patients found in folder: 08
# ⚠️ No eligible patients found in folder: 09
# ⚠️ No eligible patients found in folder: 0a
# ⚠️ No eligible patients found in folder: 0b
# ⚠️ No eligible patients found in folder: 0c
# ⚠️ No eligible patients found in folder: 0d
# ⚠️ No eligible patients found in folder: 0e
# ⚠️ No eligible patients found in folder: 0f
# ⚠️ No eligible patients found in folder: 10
# ⚠️ No eligible patients found in folder: 11
# ⚠️ No eligible patients found in folder: 12
# ⚠️ No eligible patients found in folder: 13
# ⚠️ No eligible patients found in folder: 14
# ⚠️ No eligible patients found in folder: 15
# ⚠️ No eligible patients found in folder: 16
# ⚠️ No eligible patients found in folder: 17
# ⚠️ No eligible patients found in folder: 18
# ⚠️ No eligible patients found in folder: 19
# ⚠️ No eligible patients found in folder: 1a
# ⚠️ No eligible patients found in folder: 1b
# ⚠️ No eligible patients found in folder: 1c
# ⚠️ No eligible patients found in folder: 1d
# ⚠️ No eligible patients found in folder: 1e
# ⚠️ No eligible patients found in folder: 1f
# ⚠️ No eligible patients found in folder: 20
# ⚠️ No eligible patients found in folder: 21
# ⚠️ No eligible patients found in folder: 22
# ⚠️ No eligible patients found in folder: 23
# ⚠️ No eligible patients found in folder: 24
# ⚠️ No eligible patients found in folder: 25
# ⚠️ No eligible patients found in folder: 26
# ⚠️ No eligible patients found in folder: 27
# ⚠️ No eligible patients found in folder: 28
# ⚠️ No eligible patients found in folder: 29
# ⚠️ No eligible patients found in folder: 2a
# ⚠️ No eligible patients found in folder: 2b
# ⚠️ No eligible patients found in folder: 2c
# ⚠️ No eligible patients found in folder: 2d
# ⚠️ No eligible patients found in folder: 2e
# ⚠️ No eligible patients found in folder: 2f
# ⚠️ No eligible patients found in folder: 30
# ⚠️ No eligible patients found in folder: 31
# ⚠️ No eligible patients found in folder: 32
# ⚠️ No eligible patients found in folder: 33
# ⚠️ No eligible patients found in folder: 34
# ⚠️ No eligible patients found in folder: 35
# ⚠️ No eligible patients found in folder: 36
# ⚠️ No eligible patients found in folder: 37
# ⚠️ No eligible patients found in folder: 38
# ⚠️ No eligible patients found in folder: 39
# ⚠️ No eligible patients found in folder: 3a
# ⚠️ No eligible patients found in folder: 3b
# ⚠️ No eligible patients found in folder: 3c
# ⚠️ No eligible patients found in folder: 3d
# ⚠️ No eligible patients found in folder: 3e
# ⚠️ No eligible patients found in folder: 3f
# ⚠️ No eligible patients found in folder: 40
# ⚠️ No eligible patients found in folder: 41
# ⚠️ No eligible patients found in folder: 42
# ⚠️ No eligible patients found in folder: 43
# ⚠️ No eligible patients found in folder: 44
# ⚠️ No eligible patients found in folder: 45
# ⚠️ No eligible patients found in folder: 46
# ⚠️ No eligible patients found in folder: 47
# ⚠️ No eligible patients found in folder: 48
# ⚠️ No eligible patients found in folder: 49
# ⚠️ No eligible patients found in folder: 4a
# ⚠️ No eligible patients found in folder: 4b
# ⚠️ No eligible patients found in folder: 4c
# ⚠️ No eligible patients found in folder: 4d
# ⚠️ No eligible patients found in folder: 4e
# ⚠️ No eligible patients found in folder: 4f
# ⚠️ No eligible patients found in folder: 50
# ⚠️ No eligible patients found in folder: 51
# ⚠️ No eligible patients found in folder: 52
# ⚠️ No eligible patients found in folder: 53
# ⚠️ No eligible patients found in folder: 54
# ⚠️ No eligible patients found in folder: 55
# ⚠️ No eligible patients found in folder: 56
# ⚠️ No eligible patients found in folder: 57
# ⚠️ No eligible patients found in folder: 58
# ⚠️ No eligible patients found in folder: 59
# ⚠️ No eligible patients found in folder: 5a
# ⚠️ No eligible patients found in folder: 5b
# ⚠️ No eligible patients found in folder: 5c
# ⚠️ No eligible patients found in folder: 5d
# ⚠️ No eligible patients found in folder: 5e
# ⚠️ No eligible patients found in folder: 5f
# ⚠️ No eligible patients found in folder: 60
# ⚠️ No eligible patients found in folder: 61
# ⚠️ No eligible patients found in folder: 62
# ⚠️ No eligible patients found in folder: 63
# ⚠️ No eligible patients found in folder: 64
# ⚠️ No eligible patients found in folder: 65
# ⚠️ No eligible patients found in folder: 66
# ⚠️ No eligible patients found in folder: 67
# ⚠️ No eligible patients found in folder: 68
# ⚠️ No eligible patients found in folder: 69
# ⚠️ No eligible patients found in folder: 6a
# ⚠️ No eligible patients found in folder: 6b
# ⚠️ No eligible patients found in folder: 6c
# ⚠️ No eligible patients found in folder: 6d
# ⚠️ No eligible patients found in folder: 6e
# ⚠️ No eligible patients found in folder: 6f
# ⚠️ No eligible patients found in folder: 70
# ⚠️ No eligible patients found in folder: 71
# ⚠️ No eligible patients found in folder: 72
# ⚠️ No eligible patients found in folder: 73
# ⚠️ No eligible patients found in folder: 74
# ⚠️ No eligible patients found in folder: 75
# ⚠️ No eligible patients found in folder: 76
# ⚠️ No eligible patients found in folder: 77
# ⚠️ No eligible patients found in folder: 78
# ⚠️ No eligible patients found in folder: 79
# ⚠️ No eligible patients found in folder: 7a
# ⚠️ No eligible patients found in folder: 7b
# ⚠️ No eligible patients found in folder: 7c
# ⚠️ No eligible patients found in folder: 7d
# ⚠️ No eligible patients found in folder: 7e
# ⚠️ No eligible patients found in folder: 7f
# ⚠️ No eligible patients found in folder: 80
# ⚠️ No eligible patients found in folder: 81
# ⚠️ No eligible patients found in folder: 82
# ⚠️ No eligible patients found in folder: 83
# ⚠️ No eligible patients found in folder: 84
# ⚠️ No eligible patients found in folder: 85
# ⚠️ No eligible patients found in folder: 86
# ⚠️ No eligible patients found in folder: 87
# ⚠️ No eligible patients found in folder: 88
# ⚠️ No eligible patients found in folder: 89
# ⚠️ No eligible patients found in folder: 8a
# ⚠️ No eligible patients found in folder: 8b
# ⚠️ No eligible patients found in folder: 8c
# ⚠️ No eligible patients found in folder: 8d
# ⚠️ No eligible patients found in folder: 8e
# ⚠️ No eligible patients found in folder: 8f
# ⚠️ No eligible patients found in folder: 90
# ⚠️ No eligible patients found in folder: 91
# ⚠️ No eligible patients found in folder: 92
# ⚠️ No eligible patients found in folder: 93
# ⚠️ No eligible patients found in folder: 94
# ⚠️ No eligible patients found in folder: 95
# ⚠️ No eligible patients found in folder: 96
# ⚠️ No eligible patients found in folder: 97
# ⚠️ No eligible patients found in folder: 98
# ⚠️ No eligible patients found in folder: 99
# ⚠️ No eligible patients found in folder: 9a
# ⚠️ No eligible patients found in folder: 9b
# ⚠️ No eligible patients found in folder: 9c
# ⚠️ No eligible patients found in folder: 9d
# ⚠️ No eligible patients found in folder: 9e
# ⚠️ No eligible patients found in folder: 9f
# ⚠️ No eligible patients found in folder: a0
# ⚠️ No eligible patients found in folder: a1
# ⚠️ No eligible patients found in folder: a2
# ⚠️ No eligible patients found in folder: a3
# ⚠️ No eligible patients found in folder: a4
# ⚠️ No eligible patients found in folder: a5
# ⚠️ No eligible patients found in folder: a6
# ⚠️ No eligible patients found in folder: a7
# ⚠️ No eligible patients found in folder: a8
# ⚠️ No eligible patients found in folder: a9
# ⚠️ No eligible patients found in folder: aa
# ⚠️ No eligible patients found in folder: ab
# ⚠️ No eligible patients found in folder: ac
# ⚠️ No eligible patients found in folder: ad
# ⚠️ No eligible patients found in folder: ae
# ⚠️ No eligible patients found in folder: af
# ⚠️ No eligible patients found in folder: b0
# ⚠️ No eligible patients found in folder: b1
# ⚠️ No eligible patients found in folder: b2
# ⚠️ No eligible patients found in folder: b3
# ⚠️ No eligible patients found in folder: b4
# ⚠️ No eligible patients found in folder: b5
# ⚠️ No eligible patients found in folder: b6
# ⚠️ No eligible patients found in folder: b7
# ⚠️ No eligible patients found in folder: b8
# ⚠️ No eligible patients found in folder: b9
# ⚠️ No eligible patients found in folder: ba
# ⚠️ No eligible patients found in folder: bb
# ⚠️ No eligible patients found in folder: bc
# ⚠️ No eligible patients found in folder: bd
# ⚠️ No eligible patients found in folder: be
# ⚠️ No eligible patients found in folder: bf
# ⚠️ No eligible patients found in folder: c0
# ⚠️ No eligible patients found in folder: c1
# ⚠️ No eligible patients found in folder: c2
# ⚠️ No eligible patients found in folder: c3
# ⚠️ No eligible patients found in folder: c4
# ⚠️ No eligible patients found in folder: c5
# ⚠️ No eligible patients found in folder: c6
# ⚠️ No eligible patients found in folder: c7
# ⚠️ No eligible patients found in folder: c8
# ⚠️ No eligible patients found in folder: c9
# ⚠️ No eligible patients found in folder: ca
# ⚠️ No eligible patients found in folder: cb
# ⚠️ No eligible patients found in folder: cc
# ⚠️ No eligible patients found in folder: cd
# ⚠️ No eligible patients found in folder: ce
# ⚠️ No eligible patients found in folder: cf
# ⚠️ No eligible patients found in folder: d0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 65
#      63 file_path = os.path.join(root, filename)
#      64 try:
# ---> 65     conditions = load_patient_conditions(file_path)
#      66     matched, failed = match_patient_to_criteria(conditions, structured_criteria)
#      68     if matched and not failed:
#
# Cell In[10], line 7, in load_patient_conditions(json_path)
#       6 def load_patient_conditions(json_path):
# ----> 7     with open(json_path, 'r') as file:
#       8         data = json.load(file)
#      10     conditions = []
#
# File ~\anaconda3\envs\nlp_env\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# File ~\anaconda3\envs\nlp_env\lib\codecs.py:260, in IncrementalDecoder.__init__(self, errors)
#     254 class IncrementalDecoder(object):
#     255     """
#     256     An IncrementalDecoder decodes an input in multiple steps. The input can
#     257     be passed piece by piece to the decode() method. The IncrementalDecoder
#     258     remembers the state of the decoding process between calls to decode().
#     259     """
# --> 260     def __init__(self, errors='strict'):
#     261         """
#     262         Create an IncrementalDecoder instance.
#     263
#    (...)
#     266         for a list of possible values.
#     267         """
#     268         self.errors = errors
#
# KeyboardInterrupt:
